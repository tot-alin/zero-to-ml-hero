# %%
import os
# Setează numărul de nuclee dorit (ex: 16)
n_core = "16"
os.environ["OMP_NUM_THREADS"] = n_core
os.environ["MKL_NUM_THREADS"] = n_core
os.environ["OPENBLAS_NUM_THREADS"] = n_core
os.environ["VECLIB_MAXIMUM_THREADS"] = n_core
os.environ["NUMEXPR_NUM_THREADS"] = n_core

import numpy as np
import warnings
# suppress warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import pandas as pd
import matplotlib.pyplot as plt

# %%
# data loading
data_clean = pd.read_csv("data_clean.csv")
data_clean.shape
# Out:
# (9719, 17)

# %% [markdown]
# ## Regression metrics

# %% [markdown]
# ### Mean Square Error (MSE)
# $$MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \bar{y})^2$$
# Unde:
# * $n$: The number of observations in the node.
# * $y_i$: The real value of each observation.
# * $\bar{y}$: The average of the values at that node ($\bar{y} = \frac{1}{n} \sum y_i$).

# %% [markdown]
# ### Root Mean Squared Error (RMSE)
# $$RMSE = \sqrt{\frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2}$$

# %% [markdown]
# ### ($R^2$) Score
# $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} $$

# %% [markdown]
# ## Metrics for classification

# %% [markdown]
# ### Proportionality
# $$p_i = \frac{n_i}{N}$$
# Unde:
# * **$p_i$**: Class probability or proportion $i$.
# * **$n_i$**: Number of elements (observations) in the class $i$.
# * **$N$**: Total number of elements in the dataset $S$ (unde $N = \sum n_i$).

# %% [markdown]
# ### Entropia
# $$H(S) = -\sum_{i=1}^{c} p_i \log_2(p_i)$$
# $$H(S) = - ( p_1 \log_2 p_1 + p_2 \log_2 p_2 + ... + p_i \log_2 p_i )$$
# Unde:
# * $c$: Total number of classes.
# * $p_1, p_2, p_i$:  Represents the probability (relative frequency) of each class.
# * The basic condition is that **$\sum p_i = 1$**.

# %% [raw]
# The Relationship Between Proportionality and Entropy
#
# Entropy does not react linearly to changes in proportions, but logarithmically.
# Here are the three critical states:
#
# - Extreme Proportionality (pi=1 sau pi=0):
#     If a class has a proportion of 100% (all elements are of the same kind), then log2(1)=0.
#     The entropy becomes 0. We have total certainty.
#
# - Equal Proportionality ( p1 = p2 = ...pi = 1/number of classes ):
#     When all classes have the same weight, uncertainty is maximum.
#     Entropy reaches its peak value.
#
# - Dominant Proportionality:
#     If one class has p=0.9 and the rest are insignificant, the entropy will be very low (close to 0),
#     because the set is almost pure.

# %% [markdown]
# ### Information Gain (IG)
# $$IG(S, A) = H(S) - \sum_{v \in Values(A)} \frac{|S_v|}{|S|} H(S_v)$$
#
# Unde:
# * **$H(S)$**: Entropy of the dataset before split (Parent Node).
# * **$A$**: The attribute (characteristic) based on which the split is made.
# * **$v$**: A specific attribute value $A$.
# * **$|S_v|$**: Number of elements in the sub-setul result for the value $v$.
# * **$|S|$**: Total number of elements in the parent node.
# * **$H(S_v)$**: Entropy of the resulting child node.

# %% [markdown]
# ### Gini Impurity
# $$ Gini(S) = 1 - \sum_{i=1}^{c} p_i^2 $$
# $$Gini(S) = 1 - (p_1^2 + p_2^2 + ... + p_i^2)$$
# * $Gini(S) = 0$ (All elements belong to a single class).
# * $Gini(S) = 1−(1/c)$ (Maximum uncertainty)
